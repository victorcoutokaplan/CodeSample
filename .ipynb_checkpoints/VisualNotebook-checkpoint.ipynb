# %%
import numpy as np
import matplotlib.pyplot as plt
import functions

# %% [markdown]
# ## Test data for visualization

# %%
testDict = {
    'locid1':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*15,1695445620.182882 + 43200],
                  'narcan':[0,1695445620.182882]
              }
             },


    'locid2':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*15,1695445620.182882 - 43200],
                  'narcan':[2,1695445620.182882 - 43200]
              }
             },

    'locid3':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*15,1695445620.182882 + 43200],
                  'narcan':[3,1695445620.182882 - 43200]
              }
             },

    'locid4':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*15,1695445620.182882 - 43200],
                  'narcan':[7,1695445620.182882]
              }
             },

    'locid5':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[10,1695445620.182882],
                  'narcan':[50,1695445620.182882]
              }
             },

    'locid6':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[7,1695445620.182882 - 43200],
                  'narcan':[0,1695445620.182882]
              }
             },

    'locid7':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[9,1695445620.182882],
                  'narcan':[0,1695445620.182882]
              }
             },


    'locid8':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*10,1695445620.182882 + 43200],
                  'narcan':[2,1695445620.182882]
              }
             },

    'locid9':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[3,1695445620.182882],
                  'narcan':[3,1695445620.182882 - 43200]
              }
             },

    'locid10':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*10,1695445620.182882],
                  'narcan':[7,1695445620.182882]
              }
             },

    'locid11':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[3,1695445620.182882],
                  'narcan':[50,1695445620.182882 + 43200]
              }
             },

    'locid12':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[20,1695445620.182882],
                  'narcan':[0,1695445620.182882]
              }
             },

    'locid13':{'latlong':[np.random.random()*10, np.random.random()*10],
              'stock':{
                  'covidTests':[np.random.random()*10,1695445620.182882 - 43200],
                  'narcan':[50,1695445620.182882]
              }
             },

    'locid14':{'latlong':[-3,2],
              'stock':{
                  'covidTests':[5,1695445620.182882],
                  'narcan':[0,1695445620.182882]
              }
             }
}

# %% [markdown]
# ## Animation Generation

# %%
# Set plt parameters
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 14})
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

# Set items and constants
items = ['covidTests', 'narcan']
currentTime = 1695445620.182882 + 3*86400
start = [0,0]

# Run animation generation functions
pped = functions.preProccessFilterAndComputeProbsMultipleItems(items, currentTime, testDict)
functions.drawPath(functions.minDistGradDescent(items, currentTime, testDict, start)[2], start, pped)
